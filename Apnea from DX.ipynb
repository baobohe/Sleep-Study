# %%
import numpy as np
import pandas as pd
dx = pd.read_csv('/Users/lisonghe/Library/CloudStorage/OneDrive-JohnsHopkins/Semester 2/602 Research and Design in Data Mining/files/DIAGNOSIS.csv')

# %%
dx.head(10)
# Out:
#    Unnamed: 0  STUDY_DX_ID  STUDY_ENC_ID  STUDY_PAT_ID    DX_START_DATETIME  \
# 0           0        10001      55902925         13210  2018-09-07 00:00:00
# 1           1        10017      55772269         12547  2014-11-01 00:00:00
# 2           2        10018      55772269         12547  2014-11-01 19:58:00
# 3           3        10019      55772269         12547  2014-11-01 19:58:00
# 4           4        10020      56359534          7138  2019-05-18 00:00:00
# 5           5        10021      56359534          7138  2019-05-18 00:00:00
# 6           6        10022      56359534          7138  2019-05-18 00:00:00
# 7           7        10023      56359534          7138  2019-05-18 22:50:00
# 8           8        10024      56359534          7138  2019-05-18 22:50:00
# 9           9        10025      56359534          7138  2019-05-18 22:50:00
#
#        DX_END_DATETIME          DX_SOURCE_TYPE   DX_ENC_TYPE DX_CODE_TYPE  \
# ...

# %%
merged1 = pd.read_csv('/Users/lisonghe/Library/CloudStorage/OneDrive-JohnsHopkins/Semester 2/602 Research and Design in Data Mining/merged.csv')

# %%
merged1['APNEA_NAME'].value_counts()
# Out:
# Sleep apnea, unspecified                                                         1246
# OSA (obstructive sleep apnea)                                                     542
# Obstructive sleep apnea (adult) (pediatric)                                       404
# Apnea                                                                             260
# Obstructive sleep apnea                                                           211
# Sleep apnea, unspecified type                                                      60
# Apnea, not elsewhere classified                                                    35
# Central sleep apnea                                                                31
# Unspecified sleep apnea                                                            26
# Other apnea of newborn                                                             22
# Obstructive sleep apnea syndrome                                                   21
# ...

# %%
dx[dx['DX_NAME'] == 'Central apnea']
# Out:
#          Unnamed: 0  STUDY_DX_ID  STUDY_ENC_ID  STUDY_PAT_ID  \
# 7939           7939        18482      56235709          1417
# 15144         15144        26262      55547680         11023
# 15637         15637        26793      55585048          6628
# 17347         17347        28748      56177236         18964
# 21285         21285        33107      56932873          8992
# ...             ...          ...           ...           ...
# 1489250     1489250      1621174      56509891         18391
# 1489571     1489571      1621510      56370007          4489
# 1489668     1489668      1621611      56923714         18391
# 1502105     1502105      1635341      56417506         11092
# 1509484     1509484      1643233      57059122         11023
#
#            DX_START_DATETIME      DX_END_DATETIME          DX_SOURCE_TYPE  \
# 7939     2016-07-19 00:00:00  2016-07-19 00:00:00  Secondary Encounter Dx
# 15144    2012-11-17 00:00:00  2012-11-17 00:00:00  Secondary Encounter Dx
# ...
